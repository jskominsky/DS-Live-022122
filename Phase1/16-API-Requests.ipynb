# %% [markdown]
# # Application Programming Interfaces APIs - Gathering Data Using Requests

# %% [markdown]
# ## Objectives
#
# - Send requests and receive responses over the web
# - Retrieve data from APIs using the `requests` library
# - Parse API responses

# %% [markdown]
# ## The Many Use Cases For APIs
#
# APIs can be used for many things - much more than just retrieving information. Twilio has an API that allows you to write a script to send text messages to people. GitHub has an API for creating new repositories. Many services have APIs allowing computers to automate tasks that a person might otherwise have to do through a website - whether uploading a photo to Flickr, searching for a company name in a state database, or getting a list of garbage collection times for a municipality.

# %% [markdown]
# ## Limitations of APIs
#
# When working with APIs, there are some limitations you have to be aware of - especially relating to scope and scale.
#
# * **Scope** - Just because a company has an API and has information, it doesn't mean you can get all of the information you might want through their API
#
# * **Scale** - Some APIs are provided for free as a public service. Others you have to pay for, or allow you to perform activities (like sending a text message) that you pay for. Make sure that you know what the rate limits are and that your use case isn't going to need more API calls than you will be able to make.
#
# What else is good to know? **Every API is different!** There are some standards out there in terms of documentation and usage... but it's like the wild west - rapid expansion with few rules.
#
# With all that out of the way - Let's take a look at the `requests` library and its uses.

# %% [markdown]
# ### "Requests is the only Non-GMO HTTP library for Python, safe for human consumption."
#
# > "Requests allows you to send organic, grass-fed HTTP/1.1 requests, without the need for manual labor."
#
# Straight from the `requests` [documentation](https://pypi.org/project/requests/)

# %% [markdown]
# ### Types of Requests
#
# We will mostly use GET requests in order to get data, but there are other options.
#
# ![CRUD image from IntelliPaat](https://intellipaat.com/mediaFiles/2015/08/MongoDB-CRUD-operations.jpg)
#
# That's right - CRUD summarizes the kinds of requests you can make with most APIs.
#
# Let's say you are looking at an API for a car rental company like Hertz or Zipcar - the following different requests could generate these different responses:
#
# | Request               | Result                               | In CRUD Terms |
# | --------------------- | ------------------------------------ | ------------- |
# | GET /stores/          | User sees the list of stores         | Read          |
# | GET /rentals/         | User sees the history of car rentals | Read          |
# | POST /rentals/        | User rents a car                     | Create        |
# | PUT /rentals/{id}/    | User changes destination store       | Update        |
# | DELETE /rentals/{id}/ | User cancels the active car rental   | Delete        |

# %% [markdown]
# ### Let's get started!

# %%
import requests

# %%
# Don't already have the library? Uncomment the below code and install it locally
#!pip install requests

# %%
# Create a GET request, then check the type of object

r = requests.get('https://api.github.com/events') 
type(r)
# Out:
# requests.models.Response

# %%
# So what does this look like?
r.text
# Out:
# '[{"id":"20622924599","type":"PushEvent","actor":{"id":97722808,"login":"JarkkisN","display_login":"JarkkisN","gravatar_id":"","url":"https://api.github.com/users/JarkkisN","avatar_url":"https://avatars.githubusercontent.com/u/97722808?"},"repo":{"id":467226148,"name":"JarkkisN/Olio-ohjelmointi-HAMK-2022","url":"https://api.github.com/repos/JarkkisN/Olio-ohjelmointi-HAMK-2022"},"payload":{"push_id":9287792951,"size":1,"distinct_size":1,"ref":"refs/heads/main","head":"f83d701b6ae99237c3e98f5b8517f1678759f8e1","before":"2475b18d8bea2fc2d8013b992ad0bdcaa4023332","commits":[{"sha":"f83d701b6ae99237c3e98f5b8517f1678759f8e1","author":{"email":"jarkko.niemi@student.hamk.fi","name":"Jarkko Niemi"},"message":"Lisätty Notepad-tehtävä","distinct":true,"url":"https://api.github.com/repos/JarkkisN/Olio-ohjelmointi-HAMK-2022/commits/f83d701b6ae99237c3e98f5b8517f1678759f8e1"}]},"public":true,"created_at":"2022-03-07T19:16:41Z"},{"id":"20622924584","type":"CreateEvent","actor":{"id":72580321,"login":"magarclaf","display_login":"magarclaf","gravatar_id":"","url":"https://api.github.com/users/magarclaf","avatar_url":"https://avatars.githubusercontent.com/u/72580321?"},"repo":{"id":467228059,"name":"magarclaf/Ej7P4","url":"https://api.github.com/repos/magarclaf/Ej7P4"},"payload":{"ref":"master","ref_type":"branch","master_branch":"master","description":null,"pusher_type":"user"},"public":true,"created_at":"2022-03-07T19:16:41Z"},{"id":"20622924565","type":"PushEvent","actor":{"id":22780683,"login":"DandelionSprout","display_login":"DandelionSprout","gravatar_id":"","url":"https://api.github.com/users/DandelionSprout","avatar_url":"https://avatars.githubusercontent.com/u/22780683?"},"repo":{"id":85209548,"name":"DandelionSprout/adfilt","url":"https://api.github.com/repos/DandelionSprout/adfilt"},"payload":{"push_id":9287792950,"size":1,"distinct_size":1,"ref":"refs/heads/master","head":"dd0468afda2cc639381d6624d13b3e8731171319","before":"e75eb6eacb7f41d2c49c9264f8f5b21508709a5e","commits":[{"sha":"dd0468afda2cc639381d6624d13b3e8731171319","author":{"email":"imreeil42@gmail.com","name":"Imre Kristoffer Eilertsen"},"message":"Added 1 entry\\n\\nAs per https://github.com/AdguardTeam/AdguardFilters/issues/111843","distinct":true,"url":"https://api.github.com/repos/DandelionSprout/adfilt/commits/dd0468afda2cc639381d6624d13b3e8731171319"}]},"public":true,"created_at":"2022-03-07T19:16:41Z"},{"id":"20622924591","type":"PushEvent","actor":{"id":101018947,"login":"ajaykumardangi","display_login":"ajaykumardangi","gravatar_id":"","url":"https://api.github.com/users/ajaykumardangi","avatar_url":"https://avatars.githubusercontent.com/u/101018947?"},"repo":{"id":467212717,"name":"ajaykumardangi/github-demo-remote","url":"https://api.github.com/repos/ajaykumardangi/github-demo-remote"},"payload":{"push_id":9287792958,"size":1,"distinct_size":1,"ref":"refs/heads/main","head":"d6c2b4a9d1db6e0c07eb5e134cc69c40e2b7d8da","before":"e08cd5b0ff9006e302fa76e325a137f045d56689","commits":[{"sha":"d6c2b4a9d1db6e0c07eb5e134cc69c40e2b7d8da","author":{"email":"ajay_dangi@persistent.com","name":"Ajay Dangi"},"message":"Added fn headers","distinct":true,"url":"https://api.github.com/repos/ajaykumardangi/github-demo-remote/commits/d6c2b4a9d1db6e0c07eb5e134cc69c40e2b7d8da"}]},"public":true,"created_at":"2022-03-07T19:16:41Z"},{"id":"20622924576","type":"CreateEvent","actor":{"id":8392396,"login":"turkeryi","display_login":"turkeryi","gravatar_id":"","url":"https://api.github.com/users/turkeryi","avatar_url":"https://avatars.githubusercontent.com/u/8392396?"},"repo":{"id":467227587,"name":"turkeryi/spring-graphql-example","url":"https://api.github.com/repos/turkeryi/spring-graphql-example"},"payload":{"ref":"development","ref_type":"branch","master_branch":"main","description":"Sample app using the new Spring GraphQL library.","pusher_type":"user"},"public":true,"created_at":"2022-03-07T19:16:41Z"},{"id":"20622924596","type":"PullRequestEvent","actor":{"id":49699333,"login":"depe ...

# %% [markdown]
# ![Oh good heavens gif, from gfycat](https://thumbs.gfycat.com/ColdAmbitiousDogwoodtwigborer-size_restricted.gif)

# %% [markdown]
# Obviously you're never going to just scan that quickly for any data you need, we need to wrangle that response to make it usable.
#
# But first, let's look at some of the other attributes of `requests.models.Response` objects.
#
# We can check out all of the attributes [here](https://2.python-requests.org//en/v0.10.6/api/) in the documentation.

# %%
# Another attribute, what does this show us?
r.headers
# Out:
# {'Server': 'GitHub.com', 'Date': 'Mon, 07 Mar 2022 19:21:41 GMT', 'Content-Type': 'application/json; charset=utf-8', 'Cache-Control': 'public, max-age=60, s-maxage=60', 'Vary': 'Accept, Accept-Encoding, Accept, X-Requested-With', 'ETag': 'W/"766f7ec656af221cd545dfd304f2541076923b375297af914acd7df41cfcd9bf"', 'Last-Modified': 'Mon, 07 Mar 2022 19:16:41 GMT', 'X-Poll-Interval': '60', 'X-GitHub-Media-Type': 'github.v3; format=json', 'Link': '<https://api.github.com/events?page=2>; rel="next", <https://api.github.com/events?page=10>; rel="last"', 'Access-Control-Expose-Headers': 'ETag, Link, Location, Retry-After, X-GitHub-OTP, X-RateLimit-Limit, X-RateLimit-Remaining, X-RateLimit-Used, X-RateLimit-Resource, X-RateLimit-Reset, X-OAuth-Scopes, X-Accepted-OAuth-Scopes, X-Poll-Interval, X-GitHub-Media-Type, X-GitHub-SSO, X-GitHub-Request-Id, Deprecation, Sunset', 'Access-Control-Allow-Origin': '*', 'Strict-Transport-Security': 'max-age=31536000; includeSubdomains; preload', 'X-Frame-Options': 'deny', 'X-Content-Type-Options': 'nosniff', 'X-XSS-Protection': '0', 'Referrer-Policy': 'origin-when-cross-origin, strict-origin-when-cross-origin', 'Content-Security-Policy': "default-src 'none'", 'Content-Encoding': 'gzip', 'X-RateLimit-Limit': '60', 'X-RateLimit-Remaining': '59', 'X-RateLimit-Reset': '1646684509', 'X-RateLimit-Resource': 'core', 'X-RateLimit-Used': '1', 'Accept-Ranges': 'bytes', 'Content-Length': '23832', 'X-GitHub-Request-Id': 'C93F:4878:DC96FC:1D3450A:62265B4D'}

# %% [markdown]
# ### Checking out the status of your request

# %%
# Another attribute
r.status_code
# Out:
# 200

# %% [markdown]
# ### [Types of status codes](https://http.cat/)
#
# 1xx - Informational responses
#
# 2xx - Success
# - 200 OK
# - 201 Created
# - 204 No Content
#
# 3xx - Redirection
#
# - 301 Moved Permanently (permanent URL redirection)
# - 304 Not Modified (A conditional GET or HEAD request has been received and would have resulted in a 200 OK response if it were not for the fact that the condition evaluated to false.)
#
# 4xx - Client errors
#
# - 400 Bad Request
# - 401 Unauthorized
# - 403 Forbidden
# - 404 Not Found
#
# 5xx - Server errors
#
# - 500 Internal Server Error

# %%
# Get status code for a "broken" link

r_broken = requests.get('https://api.github.com/fake-ending')
r_broken.status_code
# Out:
# 404

# %% [markdown]
# Can also explictly ask for the returned format to be json as a method.

# %%
# Going back to our working request - how does this look, compared to text?
r.json()
# Out:
# [{'id': '20622924599',
#   'type': 'PushEvent',
#   'actor': {'id': 97722808,
#    'login': 'JarkkisN',
#    'display_login': 'JarkkisN',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/JarkkisN',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/97722808?'},
#   'repo': {'id': 467226148,
#    'name': 'JarkkisN/Olio-ohjelmointi-HAMK-2022',
#    'url': 'https://api.github.com/repos/JarkkisN/Olio-ohjelmointi-HAMK-2022'},
#   'payload': {'push_id': 9287792951,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'f83d701b6ae99237c3e98f5b8517f1678759f8e1',
#    'before': '2475b18d8bea2fc2d8013b992ad0bdcaa4023332',
#    'commits': [{'sha': 'f83d701b6ae99237c3e98f5b8517f1678759f8e1',
#      'author': {'email': 'jarkko.niemi@student.hamk.fi',
#       'name': 'Jarkko Niemi'},
#      'message': 'Lisätty Notepad-tehtävä',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/JarkkisN/Olio-ohjelmointi-HAMK-2022/commits/f83d701b6ae99237c3e98f5b8517f1678759f8e1'}]},
#   'public': True,
#   'created_at': '2022-03-07T19:16:41Z'},
#  {'id': '20622924584',
#   'type': 'CreateEvent',
#   'actor': {'id': 72580321,
#    'login': 'magarclaf',
#    'display_login': 'magarclaf',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/magarclaf',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/72580321?'},
#   'repo': {'id': 467228059,
#    'name': 'magarclaf/Ej7P4',
#    'url': 'https://api.github.com/repos/magarclaf/Ej7P4'},
#   'payload': {'ref': 'master',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2022-03-07T19:16:41Z'},
#  {'id': '20622924565',
#   'type': 'PushEvent',
#   'actor': {'id': 22780683,
#    'login': 'DandelionSprout',
#    'display_login': 'DandelionSprout',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/DandelionSprout',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/22780683?'},
#   'repo': {'id': 85209548,
#    'name': 'DandelionSprout/adfilt',
#    'url': 'https://api.github.com/repos/DandelionSprout/adfilt'},
#   'payload': {'push_id': 9287792950,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'dd0468afda2cc639381d6624d13b3e8731171319',
#    'before': 'e75eb6eacb7f41d2c49c9264f8f5b21508709a5e',
#    'commits': [{'sha': 'dd0468afda2cc639381d6624d13b3e8731171319',
#      'author': {'email': 'imreeil42@gmail.com',
#       'name': 'Imre Kristoffer Eilertsen'},
#      'message': 'Added 1 entry\n\nAs per https://github.com/AdguardTeam/AdguardFilters/issues/111843',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/DandelionSprout/adfilt/commits/dd0468afda2cc639381d6624d13b3e8731171319'}]},
#   'public': True,
#   'created_at': '2022-03-07T19:16:41Z'},
#  {'id': '20622924591',
#   'type': 'PushEvent',
#   'actor': {'id': 101018947,
#    'login': 'ajaykumardangi',
#    'display_login': 'ajaykumardangi',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ajaykumardangi',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/101018947?'},
#   'repo': {'id': 467212717,
#    'name': 'ajaykumardangi/github-demo-remote',
#    'url': 'https://api.github.com/repos/ajaykumardangi/github-demo-remote'},
#   'payload': {'push_id': 9287792958,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'd6c2b4a9d1db6e0c07eb5e134cc69c40e2b7d8da',
#    'before': 'e08cd5b0ff9006e302fa76e325a137f045d56689',
#    'commits': [{'sha': 'd6c2b4a9d1db6e0c07eb5e134cc69c40e2b7d8da',
#      'author': {'email': 'ajay_dangi@persistent.com', 'name': 'Ajay Dangi'},
#      'message': 'Added fn headers',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/ajaykumardangi/github-demo-remote/commits/d6c2b4a9d1db6e0c07eb5e134cc69c40e2b7d8da'}]},
#   'public': True,
#   'created_at': '2022-03-07T19:16:41Z'},
#  {'id': '20622924576',
#   'type': 'CreateEvent',
#   'actor': {'id': 8392396,
#    'login': 'turkeryi',
#    'display_login': 'turkeryi',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/turkeryi',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8392396?'},
#   'repo': {'id': 467227587,
#    'name': 'turkeryi/spring-graphql-example',
#    'url': 'https://api.github.com/repos/turkeryi/spring-graphql-example'},
#   'payload': {'ref': 'development',
#    'ref_type': 'branch',
#    'master_branch': 'main',
#    'description': 'Sample app using the new Spring GraphQL library.',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2022-03-07T19:16:41Z'},
#  {'id': '20622924596',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 49699333,
#    'login': 'dependabot[bot]',
#    'display_login': 'dependabot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49699333?'},
#   'repo': {'id': 202914193,
#    'name': 'fisker/cin-checksum',
#    'url': 'https://api.github.com/repos/fisker/cin-checksum'},
#   'payload': {'action': 'closed',
#    'number': 1441,
#    'pull_request': {'url': 'https://api.github.com/repos/fisker/cin-checksum/pulls/1441',
#     'id': 872547820,
#     'node_id': 'PR_kwDODBg5kc40AgXs',
#     'html_url': 'https://github.com/fisker/cin-checksum/pull/1441',
#     'diff_url': 'https://github.com/fisker/cin-checksum/pull/1441.diff',
#     'patch_url': 'https://github.com/fisker/cin-checksum/pull/1441.patch',
#     'issue_url': 'https://api.github.com/repos/fisker/cin-checksum/issues/1441',
#     'number': 1441,
#     'state': 'closed',
#     'locked': False,
#     'title': 'Bump ava from 4.0.1 to 4.1.0',
#     'user': {'login': 'dependabot[bot]',
#      'id': 49699333,
#      'node_id': 'MDM6Qm90NDk2OTkzMzM=',
#      'avatar_url': 'https://avatars.githubusercontent.com/in/29110?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/dependabot%5Bbot%5D',
#      'html_url': 'https://github.com/apps/dependabot',
#      'followers_url': 'https://api.github.com/users/dependabot%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/dependabot%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/dependabot%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/dependabot%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/dependabot%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/dependabot%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/dependabot%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'site_admin': False},
#     'body': 'Bumps [ava](https://github.com/avajs/ava) from 4.0.1 to 4.1.0.\n<details>\n<summary>Release notes</summary>\n<p><em>Sourced from <a href="https://github.com/avajs/ava/releases">ava\'s releases</a>.</em></p>\n<blockquote>\n<h2>v4.1.0</h2>\n<h2>New features</h2>\n<ul>\n<li>Allow customized sorting of test files prior to execution using <code>sortTestFiles()</code> in <code>ava.config.js</code> files by <a href="https://github.com/erezrokah"><code>@\u200berezrokah</code></a> in <a href="https://github-redirect.dependabot.com/avajs/ava/pull/2968">avajs/ava#2968</a></li>\n<li>Warn when unsupported <code>ava.config.json</code> files are encountered by <a href="https://github.com/razor-x"><code>@\u200brazor-x</code></a> in <a href="https://github-redirect.dependabot.com/avajs/ava/pull/2962">avajs/ava#2962</a></li>\n<li>Loosen type constraints for <code>deepEqual</code> assertion by <a href="https://github.com/RebeccaStevens"><code>@\u200bRebeccaStevens</code></a> in <a href="https://github-redirect.dependabot.com/avajs/ava/pull/2969">avajs/ava#2969</a></li>\n</ul>\n<h2>Fixes</h2>\n<ul>\n<li><code>ava --version</code> works again by <a href="https://github.com/novemberborn"><code>@\u200bnovemberborn</code></a> in <a href="https://github-redirect.dependabot.com/avajs/ava/pull/2961">avajs/ava#2961</a></li>\n</ul>\n<h2>New Contributors</h2>\n<ul>\n<li><a href="https://github.com/sikrinick"><code>@\u200bsikrinick</code></a> made their first contribution in <a href="https://github-redirect.dependabot.com/avajs/ava/pull/2958">avajs/ava#2958</a></li>\n<li><a href="https://github.com/scottdotjs"><code>@\u200bscottdotjs</code></a> made their first contribution in <a href="https://github-redirect.dependabot.com/avajs/ava/pull/2954">avajs/ava#2954</a></li>\n<li><a href="https://github.com/gibson042"><code>@\u200bgibson042</code></a> made their first contribution in <a href="https://github-redirect.dependabot.com/avajs/ava/pull/2975">avajs/ava#2975</a></li>\n<li><a href="https://github.com/erezrokah"><code>@\u200berezrokah</code></a> made their first contribution in <a href="https://github-redirect.dependabot.com/avajs/ava/pull/2968">avajs/ava#2968</a></li>\n<li><a href="https://github.com/razor-x"><code>@\u200brazor-x</code></a> made their first contribution in <a href="https://github-redirect.dependabot.com/avajs/ava/pull/2962">avajs/ava#2962</a></li>\n<li><a href="https://github.com/RebeccaStevens"><code>@\u200bRebeccaStevens</code></a> made their first contribution in <a href="https://github-redirect.dependabot.com/avajs/ava/pull/2969">avajs/ava#2969</a></li>\n</ul>\n<p><strong>Full Changelog</strong>: <a href="https://github.com/avajs/ava/compare/v4.0.1...v4.1.0">https://github.com/avajs/ava/compare/v4.0.1...v4.1.0</a></p>\n</blockquote>\n</details>\n<details>\n<summary>Commits</summary>\n<ul>\n<li><a href="https://github.com/avajs/ava/commit/4f14c6b6dbdf9dc6487f88d2737b290dff65d5f0"><code>4f14c6b</code></a> 4.1.0</li>\n<li><a href="https://github.com/avajs/ava/commit/419047b8ffad0567cf4daf4a717a3934426e10f7"><code>419047b</code></a> Update dependencies</li>\n<li><a href="https://github.com/avajs/ava/commit/9f797b07c363201adec8e3d73c34ba1cb26056ed"><code>9f797b0</code></a> Loosen type constraints for deepEqual assertion</li>\n<li><a href="https://github.com/avajs/ava/commit/b5f934d1bff0cf74b067e1d11e552d2d56739fe3"><code>b5f934d</code></a> Add Node.js 17 reporter logs</li>\n<li><a href="https://github.com/avajs/ava/commit/9d3559338aab8c3de800404b2652747399fc1709"><code>9d35593</code></a> Warn when unsupported ava.config.json files are encountered</li>\n<li><a href="https://github.com/avajs/ava/commit/ada1a4f8876ad7b2476440609691e301a02f3951"><code>ada1a4f</code></a> Allow customized sorting of test files prior to execution</li>\n<li><a href="https://github.com/avajs/ava/commit/7276f086fb8d24625b5cb49b55557b9b48926ac0"><code>7276f08</code></a> Better explain the syntax and semantics of CLI pattern arguments</li>\n<li><a href="htt ...
#     'created_at': '2022-03-06T22:02:36Z',
#     'updated_at': '2022-03-07T19:16:41Z',
#     'closed_at': '2022-03-07T19:16:41Z',
#     'merged_at': None,
#     'merge_commit_sha': '6725206902292843c7ab98b4e0404b61c0d57527',
#     'assignee': {'login': 'fisker',
#      'id': 172584,
#      'node_id': 'MDQ6VXNlcjE3MjU4NA==',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/172584?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/fisker',
#      'html_url': 'https://github.com/fisker',
#      'followers_url': 'https://api.github.com/users/fisker/followers',
#      'following_url': 'https://api.github.com/users/fisker/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/fisker/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/fisker/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/fisker/subscriptions',
#      'organizations_url': 'https://api.github.com/users/fisker/orgs',
#      'repos_url': 'https://api.github.com/users/fisker/repos',
#      'events_url': 'https://api.github.com/users/fisker/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/fisker/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'assignees': [{'login': 'fisker',
#       'id': 172584,
#       'node_id': 'MDQ6VXNlcjE3MjU4NA==',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/172584?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/fisker',
#       'html_url': 'https://github.com/fisker',
#       'followers_url': 'https://api.github.com/users/fisker/followers',
#       'following_url': 'https://api.github.com/users/fisker/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/fisker/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/fisker/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/fisker/subscriptions',
#       'organizations_url': 'https://api.github.com/users/fisker/orgs',
#       'repos_url': 'https://api.github.com/users/fisker/repos',
#       'events_url': 'https://api.github.com/users/fisker/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/fisker/received_events',
#       'type': 'User',
#       'site_admin': False}],
#     'requested_reviewers': [{'login': 'fisker',
#       'id': 172584,
#       'node_id': 'MDQ6VXNlcjE3MjU4NA==',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/172584?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/fisker',
#       'html_url': 'https://github.com/fisker',
#       'followers_url': 'https://api.github.com/users/fisker/followers',
#       'following_url': 'https://api.github.com/users/fisker/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/fisker/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/fisker/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/fisker/subscriptions',
#       'organizations_url': 'https://api.github.com/users/fisker/orgs',
#       'repos_url': 'https://api.github.com/users/fisker/repos',
#       'events_url': 'https://api.github.com/users/fisker/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/fisker/received_events',
#       'type': 'User',
#       'site_admin': False}],
#     'requested_teams': [],
#     'labels': [{'id': 1505661855,
#       'node_id': 'MDU6TGFiZWwxNTA1NjYxODU1',
#       'url': 'https://api.github.com/repos/fisker/cin-checksum/labels/dependencies',
#       'name': 'dependencies',
#       'color': '0366d6',
#       'default': False,
#       'description': 'Pull requests that update a dependency file'},
#      {'id': 2131158203,
#       'node_id': 'MDU6TGFiZWwyMTMxMTU4MjAz',
#       'url': 'https://api.github.com/repos/fisker/cin-checksum/labels/javascript',
#       'name': 'javascript',
#       'color': '168700',
#       'default': False,
#       'description': 'Pull requests that update Javascript code'}],
#     'milestone': None,
#     'draft': False,
#     'commits_url': 'https://api.github.com/repos/fisker/cin-checksum/pulls/1441/commits',
#     'review_comments_url': 'https://api.github.com/repos/fisker/cin-checksum/pulls/1441/comments',
#     'review_comment_url': 'https://api.github.com/repos/fisker/cin-checksum/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/fisker/cin-checksum/issues/1441/comments',
#     'statuses_url': 'https://api.github.com/repos/fisker/cin-checksum/statuses/3e687035254f71862ea121e7247e92126f156e83',
#     'head': {'label': 'fisker:dependabot/npm_and_yarn/ava-4.1.0',
#      'ref': 'dependabot/npm_and_yarn/ava-4.1.0',
#      'sha': '3e687035254f71862ea121e7247e92126f156e83',
#      'user': {'login': 'fisker',
#       'id': 172584,
#       'node_id': 'MDQ6VXNlcjE3MjU4NA==',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/172584?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/fisker',
#       'html_url': 'https://github.com/fisker',
#       'followers_url': 'https://api.github.com/users/fisker/followers',
#       'following_url': 'https://api.github.com/users/fisker/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/fisker/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/fisker/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/fisker/subscriptions',
#       'organizations_url': 'https://api.github.com/users/fisker/orgs',
#       'repos_url': 'https://api.github.com/users/fisker/repos',
#       'events_url': 'https://api.github.com/users/fisker/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/fisker/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 202914193,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkyMDI5MTQxOTM=',
#       'name': 'cin-checksum',
#       'full_name': 'fisker/cin-checksum',
#       'private': False,
#       'owner': {'login': 'fisker',
#        'id': 172584,
#        'node_id': 'MDQ6VXNlcjE3MjU4NA==',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/172584?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/fisker',
#        'html_url': 'https://github.com/fisker',
#        'followers_url': 'https://api.github.com/users/fisker/followers',
#        'following_url': 'https://api.github.com/users/fisker/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/fisker/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/fisker/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/fisker/subscriptions',
#        'organizations_url': 'https://api.github.com/users/fisker/orgs',
#        'repos_url': 'https://api.github.com/users/fisker/repos',
#        'events_url': 'https://api.github.com/users/fisker/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/fisker/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/fisker/cin-checksum',
#       'description': 'Citizen identification number(GB 11643-1999) Checksum',
#       'fork': False,
#       'url': 'https://api.github.com/repos/fisker/cin-checksum',
#       'forks_url': 'https://api.github.com/repos/fisker/cin-checksum/forks',
#       'keys_url': 'https://api.github.com/repos/fisker/cin-checksum/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/fisker/cin-checksum/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/fisker/cin-checksum/teams',
#       'hooks_url': 'https://api.github.com/repos/fisker/cin-checksum/hooks',
#       'issue_events_url': 'https://api.github.com/repos/fisker/cin-checksum/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/fisker/cin-checksum/events',
#       'assignees_url': 'https://api.github.com/repos/fisker/cin-checksum/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/fisker/cin-checksum/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/fisker/cin-checksum/tags',
#       'blobs_url': 'https://api.github.com/repos/fisker/cin-checksum/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/fisker/cin-checksum/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/fisker/cin-checksum/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/fisker/cin-checksum/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/fisker/cin-checksum/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/fisker/cin-checksum/languages',
#       'stargazers_url': 'https://api.github.com/repos/fisker/cin-checksum/stargazers',
#       'contributors_url': 'https://api.github.com/repos/fisker/cin-checksum/contributors',
#       'subscribers_url': 'https://api.github.com/repos/fisker/cin-checksum/subscribers',
#       'subscription_url': 'https://api.github.com/repos/fisker/cin-checksum/subscription',
#       'commits_url': 'https://api.github.com/repos/fisker/cin-checksum/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/fisker/cin-checksum/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/fisker/cin-checksum/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/fisker/cin-checksum/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/fisker/cin-checksum/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/fisker/cin-checksum/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/fisker/cin-checksum/merges',
#       'archive_url': 'https://api.github.com/repos/fisker/cin-checksum/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/fisker/cin-checksum/downloads',
#       'issues_url': 'https://api.github.com/repos/fisker/cin-checksum/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/fisker/cin-checksum/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/fisker/cin-checksum/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/fisker/cin-checksum/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/fisker/cin-checksum/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/fisker/cin-checksum/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/fisker/cin-checksum/deployments',
#       'created_at': '2019-08-17T17:46:13Z',
#       'updated_at': '2022-01-17T02:39:49Z',
#       'pushed_at': '2022-03-07T19:16:23Z',
#       'git_url': 'git://github.com/fisker/cin-checksum.git',
#       'ssh_url': 'git@github.com:fisker/cin-checksum.git',
#       'clone_url': 'https://github.com/fisker/cin-checksum.git',
#       'svn_url': 'https://github.com/fisker/cin-checksum',
#       'homepage': None,
#       'size': 587,
#       'stargazers_count': 1,
#       'watchers_count': 1,
#       'language': 'JavaScript',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 2,
#       'license': {'key': 'mit',
#        'name': 'MIT License',
#        'spdx_id': 'MIT',
#        'url': 'https://api.github.com/licenses/mit',
#        'node_id': 'MDc6TGljZW5zZTEz'},
#       'allow_forking': True,
#       'is_template': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 0,
#       'open_issues': 2,
#       'watchers': 1,
#       'default_branch': 'main'}},
#     'base': {'label': 'fisker:main',
#      'ref': 'main',
#      'sha': 'eb2fb80c7435349c307b7b3053be1575b4316b42',
#      'user': {'login': 'fisker',
#       'id': 172584,
#       'node_id': 'MDQ6VXNlcjE3MjU4NA==',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/172584?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/fisker',
#       'html_url': 'https://github.com/fisker',
#       'followers_url': 'https://api.github.com/users/fisker/followers',
#       'following_url': 'https://api.github.com/users/fisker/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/fisker/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/fisker/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/fisker/subscriptions',
#       'organizations_url': 'https://api.github.com/users/fisker/orgs',
#       'repos_url': 'https://api.github.com/users/fisker/repos',
#       'events_url': 'https://api.github.com/users/fisker/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/fisker/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 202914193,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkyMDI5MTQxOTM=',
#       'name': 'cin-checksum',
#       'full_name': 'fisker/cin-checksum',
#       'private': False,
#       'owner': {'login': 'fisker',
#        'id': 172584,
#        'node_id': 'MDQ6VXNlcjE3MjU4NA==',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/172584?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/fisker',
#        'html_url': 'https://github.com/fisker',
#        'followers_url': 'https://api.github.com/users/fisker/followers',
#        'following_url': 'https://api.github.com/users/fisker/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/fisker/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/fisker/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/fisker/subscriptions',
#        'organizations_url': 'https://api.github.com/users/fisker/orgs',
#        'repos_url': 'https://api.github.com/users/fisker/repos',
#        'events_url': 'https://api.github.com/users/fisker/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/fisker/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/fisker/cin-checksum',
#       'description': 'Citizen identification number(GB 11643-1999) Checksum',
#       'fork': False,
#       'url': 'https://api.github.com/repos/fisker/cin-checksum',
#       'forks_url': 'https://api.github.com/repos/fisker/cin-checksum/forks',
#       'keys_url': 'https://api.github.com/repos/fisker/cin-checksum/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/fisker/cin-checksum/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/fisker/cin-checksum/teams',
#       'hooks_url': 'https://api.github.com/repos/fisker/cin-checksum/hooks',
#       'issue_events_url': 'https://api.github.com/repos/fisker/cin-checksum/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/fisker/cin-checksum/events',
#       'assignees_url': 'https://api.github.com/repos/fisker/cin-checksum/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/fisker/cin-checksum/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/fisker/cin-checksum/tags',
#       'blobs_url': 'https://api.github.com/repos/fisker/cin-checksum/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/fisker/cin-checksum/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/fisker/cin-checksum/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/fisker/cin-checksum/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/fisker/cin-checksum/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/fisker/cin-checksum/languages',
#       'stargazers_url': 'https://api.github.com/repos/fisker/cin-checksum/stargazers',
#       'contributors_url': 'https://api.github.com/repos/fisker/cin-checksum/contributors',
#       'subscribers_url': 'https://api.github.com/repos/fisker/cin-checksum/subscribers',
#       'subscription_url': 'https://api.github.com/repos/fisker/cin-checksum/subscription',
#       'commits_url': 'https://api.github.com/repos/fisker/cin-checksum/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/fisker/cin-checksum/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/fisker/cin-checksum/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/fisker/cin-checksum/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/fisker/cin-checksum/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/fisker/cin-checksum/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/fisker/cin-checksum/merges',
#       'archive_url': 'https://api.github.com/repos/fisker/cin-checksum/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/fisker/cin-checksum/downloads',
#       'issues_url': 'https://api.github.com/repos/fisker/cin-checksum/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/fisker/cin-checksum/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/fisker/cin-checksum/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/fisker/cin-checksum/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/fisker/cin-checksum/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/fisker/cin-checksum/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/fisker/cin-checksum/deployments',
#       'created_at': '2019-08-17T17:46:13Z',
#       'updated_at': '2022-01-17T02:39:49Z',
#       'pushed_at': '2022-03-07T19:16:23Z',
#       'git_url': 'git://github.com/fisker/cin-checksum.git',
#       'ssh_url': 'git@github.com:fisker/cin-checksum.git',
#       'clone_url': 'https://github.com/fisker/cin-checksum.git',
#       'svn_url': 'https://github.com/fisker/cin-checksum',
#       'homepage': None,
#       'size': 587,
#       'stargazers_count': 1,
#       'watchers_count': 1,
#       'language': 'JavaScript',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 2,
#       'license': {'key': 'mit',
#        'name': 'MIT License',
#        'spdx_id': 'MIT',
#        'url': 'https://api.github.com/licenses/mit',
#        'node_id': 'MDc6TGljZW5zZTEz'},
#       'allow_forking': True,
#       'is_template': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 0,
#       'open_issues': 2,
#       'watchers': 1,
#       'default_branch': 'main'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/fisker/cin-checksum/pulls/1441'},
#      'html': {'href': 'https://github.com/fisker/cin-checksum/pull/1441'},
#      'issue': {'href': 'https://api.github.com/repos/fisker/cin-checksum/issues/1441'},
#      'comments': {'href': 'https://api.github.com/repos/fisker/cin-checksum/issues/1441/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/fisker/cin-checksum/pulls/1441/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/fisker/cin-checksum/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/fisker/cin-checksum/pulls/1441/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/fisker/cin-checksum/statuses/3e687035254f71862ea121e7247e92126f156e83'}},
#     'author_association': 'CONTRIBUTOR',
#     'auto_merge': None,
#     'active_lock_reason': None,
#     'merged': False,
#     'mergeable': True,
#     'rebaseable': True,
#     'mergeable_state': 'clean',
#     'merged_by': None,
#     'comments': 1,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 1,
#     'additions': 1,
#     'deletions': 1,
#     'changed_files': 1}},
#   'public': True,
#   'created_at': '2022-03-07T19:16:41Z'},
#  {'id': '20622924566',
#   'type': 'DeleteEvent',
#   'actor': {'id': 73136330,
#    'login': 'DTrombett',
#    'display_login': 'DTrombett',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/DTrombett',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/73136330?'},
#   'repo': {'id': 399174757,
#    'name': 'DTrombett/github-bot',
#    'url': 'https://api.github.com/repos/DTrombett/github-bot'},
#   'payload': {'ref': 'dependabot/npm_and_yarn/sapphire/async-queue-1.3.0',
#    'ref_type': 'branch',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2022-03-07T19:16:41Z'},
#  {'id': '20622923948',
#   'type': 'ReleaseEvent',
#   'actor': {'id': 30523469,
#    'login': 'zww0019',
#    'display_login': 'zww0019',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/zww0019',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/30523469?'},
#   'repo': {'id': 420633429,
#    'name': 'zww0019/zww0019pic',
#    'url': 'https://api.github.com/repos/zww0019/zww0019pic'},
#   'payload': {'action': 'published',
#    'release': {'url': 'https://api.github.com/repos/zww0019/zww0019pic/releases/61190210',
#     'assets_url': 'https://api.github.com/repos/zww0019/zww0019pic/releases/61190210/assets',
#     'upload_url': 'https://uploads.github.com/repos/zww0019/zww0019pic/releases/61190210/assets{?name,label}',
#     'html_url': 'https://github.com/zww0019/zww0019pic/releases/tag/latest',
#     'id': 61190210,
#     'author': {'login': 'zww0019',
#      'id': 30523469,
#      'node_id': 'MDQ6VXNlcjMwNTIzNDY5',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/30523469?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/zww0019',
#      'html_url': 'https://github.com/zww0019',
#      'followers_url': 'https://api.github.com/users/zww0019/followers',
#      'following_url': 'https://api.github.com/users/zww0019/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/zww0019/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/zww0019/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/zww0019/subscriptions',
#      'organizations_url': 'https://api.github.com/users/zww0019/orgs',
#      'repos_url': 'https://api.github.com/users/zww0019/repos',
#      'events_url': 'https://api.github.com/users/zww0019/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/zww0019/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'node_id': 'RE_kwDOGRJbVc4DpbBC',
#     'tag_name': 'latest',
#     'target_commitish': 'main',
#     'name': 'latest',
#     'draft': False,
#     'prerelease': False,
#     'created_at': '2022-03-07T19:16:38Z',
#     'published_at': '2022-03-07T19:16:39Z',
#     'assets': [],
#     'tarball_url': 'https://api.github.com/repos/zww0019/zww0019pic/tarball/latest',
#     'zipball_url': 'https://api.github.com/repos/zww0019/zww0019pic/zipball/latest',
#     'body': None,
#     'short_description_html': '',
#     'is_short_description_html_truncated': False}},
#   'public': True,
#   'created_at': '2022-03-07T19:16:39Z'},
#  {'id': '20622924570',
#   'type': 'PushEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 449620792,
#    'name': 'factcheckr/uppity',
#    'url': 'https://api.github.com/repos/factcheckr/uppity'},
#   'payload': {'push_id': 9287792938,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/gh-pages',
#    'head': 'f10cba7c9d859cc7a66610a43f7642112b7efa8d',
#    'before': 'a5a40567c16ad95891125b3abc1a2525d43cbdaa',
#    'commits': [{'sha': 'f10cba7c9d859cc7a66610a43f7642112b7efa8d',
#      'author': {'email': 'amblerkr@users.noreply.github.com',
#       'name': 'amblerkr'},
#      'message': 'Deploying to GitHub Pages from 079c3441ac1e6570a4aa73a849131b26308a7b0a',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/factcheckr/uppity/commits/f10cba7c9d859cc7a66610a43f7642112b7efa8d'}]},
#   'public': True,
#   'created_at': '2022-03-07T19:16:41Z',
#   'org': {'id': 91438245,
#    'login': 'factcheckr',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/factcheckr',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/91438245?'}},
#  {'id': '20622924527',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 49699333,
#    'login': 'dependabot[bot]',
#    'display_login': 'dependabot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49699333?'},
#   'repo': {'id': 311476880,
#    'name': 'julianKatz/gatekeeper',
#    'url': 'https://api.github.com/repos/julianKatz/gatekeeper'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/julianKatz/gatekeeper/issues/80',
#     'repository_url': 'https://api.github.com/repos/julianKatz/gatekeeper',
#     'labels_url': 'https://api.github.com/repos/julianKatz/gatekeeper/issues/80/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/julianKatz/gatekeeper/issues/80/comments',
#     'events_url': 'https://api.github.com/repos/julianKatz/gatekeeper/issues/80/events',
#     'html_url': 'https://github.com/julianKatz/gatekeeper/pull/80',
#     'id': 1158964484,
#     'node_id': 'PR_kwDOEpDCkM4z64sH',
#     'number': 80,
#     'title': 'chore: bump @docusaurus/core from 2.0.0-beta.16 to 2.0.0-beta.17 in /website',
#     'user': {'login': 'dependabot[bot]',
#      'id': 49699333,
#      'node_id': 'MDM6Qm90NDk2OTkzMzM=',
#      'avatar_url': 'https://avatars.githubusercontent.com/in/29110?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/dependabot%5Bbot%5D',
#      'html_url': 'https://github.com/apps/dependabot',
#      'followers_url': 'https://api.github.com/users/dependabot%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/dependabot%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/dependabot%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/dependabot%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/dependabot%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/dependabot%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/dependabot%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'site_admin': False},
#     'labels': [{'id': 2920931303,
#       'node_id': 'MDU6TGFiZWwyOTIwOTMxMzAz',
#       'url': 'https://api.github.com/repos/julianKatz/gatekeeper/labels/dependencies',
#       'name': 'dependencies',
#       'color': '0366d6',
#       'default': False,
#       'description': 'Pull requests that update a dependency file'},
#      {'id': 2920932342,
#       'node_id': 'MDU6TGFiZWwyOTIwOTMyMzQy',
#       'url': 'https://api.github.com/repos/julianKatz/gatekeeper/labels/javascript',
#       'name': 'javascript',
#       'color': '168700',
#       'default': False,
#       'description': 'Pull requests that update Javascript code'}],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 0,
#     'created_at': '2022-03-03T22:19:09Z',
#     'updated_at': '2022-03-07T19:16:41Z',
#     'closed_at': None,
#     'author_association': 'NONE',
#     'active_lock_reason': None,
#     'draft': False,
#     'pull_request': {'url': 'https://api.github.com/repos/julianKatz/gatekeeper/pulls/80',
#      'html_url': 'https://github.com/julianKatz/gatekeeper/pull/80',
#      'diff_url': 'https://github.com/julianKatz/gatekeeper/pull/80.diff',
#      'patch_url': 'https://github.com/julianKatz/gatekeeper/pull/80.patch',
#      'merged_at': None},
#     'body': '[//]: # (dependabot-start)\n⚠️  **Dependabot is rebasing this PR** ⚠️ \n\nRebasing might not happen immediately, so don\'t worry if this takes some time.\n\nNote: if you make any changes to this PR yourself, they will take precedence over the rebase.\n\n---\n\n[//]: # (dependabot-end)\n\nBumps [@docusaurus/core](https://github.com/facebook/docusaurus/tree/HEAD/packages/docusaurus) from 2.0.0-beta.16 to 2.0.0-beta.17.\n<details>\n<summary>Release notes</summary>\n<p><em>Sourced from <a href="https://github.com/facebook/docusaurus/releases"><code>@\u200bdocusaurus/core</code>\'s releases</a>.</em></p>\n<blockquote>\n<h2>2.0.0-beta.17 (2022-03-03)</h2>\n<h4>:rocket: New Feature</h4>\n<ul>\n<li><code>docusaurus-plugin-content-blog</code>, <code>docusaurus-theme-classic</code>\n<ul>\n<li><a href="https://github-redirect.dependabot.com/facebook/docusaurus/pull/6783">#6783</a> feat: allow blog authors email (<a href="https://github.com/Josh-Cena"><code>@\u200bJosh-Cena</code></a>)</li>\n</ul>\n</li>\n</ul>\n<h4>:boom: Breaking Change</h4>\n<ul>\n<li><code>docusaurus-theme-classic</code>, <code>docusaurus-theme-common</code>\n<ul>\n<li><a href="https://github-redirect.dependabot.com/facebook/docusaurus/pull/6771">#6771</a> refactor(theme-classic): replace color mode toggle with button; remove switchConfig (<a href="https://github.com/Josh-Cena"><code>@\u200bJosh-Cena</code></a>)</li>\n</ul>\n</li>\n</ul>\n<h4>:bug: Bug Fix</h4>\n<ul>\n<li><code>docusaurus-theme-classic</code>\n<ul>\n<li><a href="https://github-redirect.dependabot.com/facebook/docusaurus/pull/6827">#6827</a> fix(theme-classic): restore docusaurus search meta (<a href="https://github.com/slorber"><code>@\u200bslorber</code></a>)</li>\n<li><a href="https://github-redirect.dependabot.com/facebook/docusaurus/pull/6767">#6767</a> fix(theme-classic): allow code tags containing inline elements to stay inline (<a href="https://github.com/Josh-Cena"><code>@\u200bJosh-Cena</code></a>)</li>\n</ul>\n</li>\n<li><code>docusaurus-theme-common</code>\n<ul>\n<li><a href="https://github-redirect.dependabot.com/facebook/docusaurus/pull/6824">#6824</a> fix(theme-common): breadcrumbs home bug in docs-only (<a href="https://github.com/slorber"><code>@\u200bslorber</code></a>)</li>\n<li><a href="https://github-redirect.dependabot.com/facebook/docusaurus/pull/6816">#6816</a> fix(theme-common): docs breadcrumbs not working with baseUrl (<a href="https://github.com/slorber"><code>@\u200bslorber</code></a>)</li>\n</ul>\n</li>\n<li><code>docusaurus-plugin-content-docs</code>\n<ul>\n<li><a href="https://github-redirect.dependabot.com/facebook/docusaurus/pull/6700">#6700</a> fix(content-docs): always sort autogenerated sidebar items by file/folder name by default (<a href="https://github.com/Josh-Cena"><code>@\u200bJosh-Cena</code></a>)</li>\n</ul>\n</li>\n<li><code>docusaurus</code>\n<ul>\n<li><a href="https://github-redirect.dependabot.com/facebook/docusaurus/pull/6812">#6812</a> fix(core): remove hash/query when filtering existing files for broken link check (<a href="https://github.com/Josh-Cena"><code>@\u200bJosh-Cena</code></a>)</li>\n</ul>\n</li>\n<li><code>docusaurus-mdx-loader</code>\n<ul>\n<li><a href="https://github-redirect.dependabot.com/facebook/docusaurus/pull/6779">#6779</a> fix(mdx-loader): suppress image reading warning in Yarn PnP; log warning instead of error (<a href="https://github.com/Josh-Cena"><code>@\u200bJosh-Cena</code></a>)</li>\n</ul>\n</li>\n<li><code>create-docusaurus</code>\n<ul>\n<li><a href="https://github-redirect.dependabot.com/facebook/docusaurus/pull/6762">#6762</a> fix(create): update broken SVG paths in templates (<a href="https://github.com/anicholls"><code>@\u200banicholls</code></a>)</li>\n</ul>\n</li>\n</ul>\n<h4>:nail_care: Polish</h4>\n<ul>\n<li><code>docusaurus-theme-common</code>\n<ul>\n<li><a href="https://github-redirect.dependabot.com/facebook/docusaurus/pull/6826">#6826</a> refactor(theme-common): unify missing context errors (<a hre ...
#     'reactions': {'url': 'https://api.github.com/repos/julianKatz/gatekeeper/issues/80/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'timeline_url': 'https://api.github.com/repos/julianKatz/gatekeeper/issues/80/timeline',
#     'performed_via_github_app': None},
#    'comment': {'url': 'https://api.github.com/repos/julianKatz/gatekeeper/issues/comments/1061040875',
#     'html_url': 'https://github.com/julianKatz/gatekeeper/pull/80#issuecomment-1061040875',
#     'issue_url': 'https://api.github.com/repos/julianKatz/gatekeeper/issues/80',
#     'id': 1061040875,
#     'node_id': 'IC_kwDOEpDCkM4_PjLr',
#     'user': {'login': 'dependabot[bot]',
#      'id': 49699333,
#      'node_id': 'MDM6Qm90NDk2OTkzMzM=',
#      'avatar_url': 'https://avatars.githubusercontent.com/in/29110?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/dependabot%5Bbot%5D',
#      'html_url': 'https://github.com/apps/dependabot',
#      'followers_url': 'https://api.github.com/users/dependabot%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/dependabot%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/dependabot%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/dependabot%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/dependabot%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/dependabot%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/dependabot%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'site_admin': False},
#     'created_at': '2022-03-07T19:16:41Z',
#     'updated_at': '2022-03-07T19:16:41Z',
#     'author_association': 'NONE',
#     'body': 'Looks like @docusaurus/core is up-to-date now, so this is no longer needed.',
#     'reactions': {'url': 'https://api.github.com/repos/julianKatz/gatekeeper/issues/comments/1061040875/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'performed_via_github_app': None}},
#   'public': True,
#   'created_at': '2022-03-07T19:16:41Z'},
#  {'id': '20622924523',
#   'type': 'PushEvent',
#   'actor': {'id': 35656197,
#    'login': 'matheus55391',
#    'display_login': 'matheus55391',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/matheus55391',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/35656197?'},
#   'repo': {'id': 465108847,
#    'name': 'matheus55391/eCommerce_projeto',
#    'url': 'https://api.github.com/repos/matheus55391/eCommerce_projeto'},
#   'payload': {'push_id': 9287792939,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '2be6237fad48bd075e7a8372a5543ba4e7a82c71',
#    'before': 'c441a76c8f0716898152c5f3e34e8c60eef1a8bf',
#    'commits': [{'sha': '2be6237fad48bd075e7a8372a5543ba4e7a82c71',
#      'author': {'email': 'matheus.manulo55@gmail.com', 'name': 'matheus55391'},
#      'message': 'Finalizando projetinho',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/matheus55391/eCommerce_projeto/commits/2be6237fad48bd075e7a8372a5543ba4e7a82c71'}]},
#   'public': True,
#   'created_at': '2022-03-07T19:16:41Z'},
#  {'id': '20622924539',
#   'type': 'PushEvent',
#   'actor': {'id': 96521340,
#    'login': 'goreadmenow',
#    'display_login': 'goreadmenow',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/goreadmenow',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/96521340?'},
#   'repo': {'id': 467206059,
#    'name': 'goreadmenow/forkmenow',
#    'url': 'https://api.github.com/repos/goreadmenow/forkmenow'},
#   'payload': {'push_id': 9287792943,
#    'size': 2,
#    'distinct_size': 2,
#    'ref': 'refs/heads/main',
#    'head': '456a65361ca55b6314036e303640411d5b11105b',
#    'before': '1290506e857f42c33d8c419911593edc3270b38c',
#    'commits': [{'sha': '9cc21e41f6838b10dc535a4b9bea8e49bcf2a85c',
#      'author': {'email': 'rival_b@yahoo.com', 'name': 'xcyrax'},
#      'message': 'xcyrax menambahkan satu file baru index.html pada repo forkmenow',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/goreadmenow/forkmenow/commits/9cc21e41f6838b10dc535a4b9bea8e49bcf2a85c'},
#     {'sha': '456a65361ca55b6314036e303640411d5b11105b',
#      'author': {'email': '96521340+goreadmenow@users.noreply.github.com',
#       'name': 'goreadmenow'},
#      'message': 'Merge pull request #1 from xcyrax/main\n\nxcyrax menambahkan satu file baru index.html pada repo forkmenow',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/goreadmenow/forkmenow/commits/456a65361ca55b6314036e303640411d5b11105b'}]},
#   'public': True,
#   'created_at': '2022-03-07T19:16:41Z'},
#  {'id': '20622924535',
#   'type': 'PushEvent',
#   'actor': {'id': 7249208,
#    'login': 'Shabirmean',
#    'display_login': 'Shabirmean',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Shabirmean',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/7249208?'},
#   'repo': {'id': 274702607,
#    'name': 'GoogleCloudPlatform/anthos-samples',
#    'url': 'https://api.github.com/repos/GoogleCloudPlatform/anthos-samples'},
#   'payload': {'push_id': 9287792927,
#    'size': 2,
#    'distinct_size': 1,
#    'ref': 'refs/heads/check-abm-install',
#    'head': '07f6dda77f6c72e94795a43d4f42a94a3511922a',
#    'before': '118723efbef6a828c0227c981294c66b344aa70c',
# ...
#        'starred_url': 'https://api.github.com/users/NouamaneTazi/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/NouamaneTazi/subscriptions',
#        'organizations_url': 'https://api.github.com/users/NouamaneTazi/orgs',
#        'repos_url': 'https://api.github.com/users/NouamaneTazi/repos',
#        'events_url': 'https://api.github.com/users/NouamaneTazi/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/NouamaneTazi/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/NouamaneTazi/NouamaneTazi',
#       'description': None,
#       'fork': False,
#       'url': 'https://api.github.com/repos/NouamaneTazi/NouamaneTazi',
#       'forks_url': 'https://api.github.com/repos/NouamaneTazi/NouamaneTazi/forks',
#       'keys_url': 'https://api.github.com/repos/NouamaneTazi/NouamaneTazi/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/NouamaneTazi/NouamaneTazi/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/NouamaneTazi/NouamaneTazi/teams',
#       'hooks_url': 'https://api.github.com/repos/NouamaneTazi/NouamaneTazi/hooks',
#       'issue_events_url': 'https://api.github.com/repos/NouamaneTazi/NouamaneTazi/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/NouamaneTazi/NouamaneTazi/events',
#       'assignees_url': 'https://api.github.com/repos/NouamaneTazi/NouamaneTazi/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/NouamaneTazi/NouamaneTazi/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/NouamaneTazi/NouamaneTazi/tags',
#       'blobs_url': 'https://api.github.com/repos/NouamaneTazi/NouamaneTazi/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/NouamaneTazi/NouamaneTazi/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/NouamaneTazi/NouamaneTazi/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/NouamaneTazi/NouamaneTazi/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/NouamaneTazi/NouamaneTazi/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/NouamaneTazi/NouamaneTazi/languages',
#       'stargazers_url': 'https://api.github.com/repos/NouamaneTazi/NouamaneTazi/stargazers',
#       'contributors_url': 'https://api.github.com/repos/NouamaneTazi/NouamaneTazi/contributors',
#       'subscribers_url': 'https://api.github.com/repos/NouamaneTazi/NouamaneTazi/subscribers',
#       'subscription_url': 'https://api.github.com/repos/NouamaneTazi/NouamaneTazi/subscription',
#       'commits_url': 'https://api.github.com/repos/NouamaneTazi/NouamaneTazi/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/NouamaneTazi/NouamaneTazi/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/NouamaneTazi/NouamaneTazi/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/NouamaneTazi/NouamaneTazi/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/NouamaneTazi/NouamaneTazi/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/NouamaneTazi/NouamaneTazi/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/NouamaneTazi/NouamaneTazi/merges',
#       'archive_url': 'https://api.github.com/repos/NouamaneTazi/NouamaneTazi/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/NouamaneTazi/NouamaneTazi/downloads',
#       'issues_url': 'https://api.github.com/repos/NouamaneTazi/NouamaneTazi/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/NouamaneTazi/NouamaneTazi/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/NouamaneTazi/NouamaneTazi/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/NouamaneTazi/NouamaneTazi/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/NouamaneTazi/NouamaneTazi/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/NouamaneTazi/NouamaneTazi/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/NouamaneTazi/NouamaneTazi/deployments',
#       'created_at': '2021-01-16T21:03:36Z',
#       'updated_at': '2022-01-12T13:10:21Z',
#       'pushed_at': '2022-03-07T19:16:40Z',
#       'git_url': 'git://github.com/NouamaneTazi/NouamaneTazi.git',
#       'ssh_url': 'git@github.com:NouamaneTazi/NouamaneTazi.git',
#       'clone_url': 'https://github.com/NouamaneTazi/NouamaneTazi.git',
#       'svn_url': 'https://github.com/NouamaneTazi/NouamaneTazi',
#       'homepage': None,
#       'size': 4547,
#       'stargazers_count': 5,
#       'watchers_count': 5,
#       'language': None,
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 2,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 14,
#       'license': None,
#       'allow_forking': True,
#       'is_template': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 2,
#       'open_issues': 14,
#       'watchers': 5,
#       'default_branch': 'main'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/NouamaneTazi/NouamaneTazi/pulls/1281'},
#      'html': {'href': 'https://github.com/NouamaneTazi/NouamaneTazi/pull/1281'},
#      'issue': {'href': 'https://api.github.com/repos/NouamaneTazi/NouamaneTazi/issues/1281'},
#      'comments': {'href': 'https://api.github.com/repos/NouamaneTazi/NouamaneTazi/issues/1281/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/NouamaneTazi/NouamaneTazi/pulls/1281/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/NouamaneTazi/NouamaneTazi/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/NouamaneTazi/NouamaneTazi/pulls/1281/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/NouamaneTazi/NouamaneTazi/statuses/5d8ef99d45755c7f4685732347193ff1082b901f'}},
#     'author_association': 'CONTRIBUTOR',
#     'auto_merge': None,
#     'active_lock_reason': None,
#     'merged': True,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': {'login': 'github-actions[bot]',
#      'id': 41898282,
#      'node_id': 'MDM6Qm90NDE4OTgyODI=',
#      'avatar_url': 'https://avatars.githubusercontent.com/in/15368?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/github-actions%5Bbot%5D',
#      'html_url': 'https://github.com/apps/github-actions',
#      'followers_url': 'https://api.github.com/users/github-actions%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/github-actions%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/github-actions%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/github-actions%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/github-actions%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/github-actions%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/github-actions%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/github-actions%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/github-actions%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'site_admin': False},
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 1,
#     'additions': 3,
#     'deletions': 3,
#     'changed_files': 1}},
#   'public': True,
#   'created_at': '2022-03-07T19:16:41Z'},
#  {'id': '20622924520',
#   'type': 'PushEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 388248644,
#    'name': 'atom-packages/feed',
#    'url': 'https://api.github.com/repos/atom-packages/feed'},
#   'payload': {'push_id': 9287792926,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/gh-pages',
#    'head': '57790bff988ef155051081c930957c46e90823a3',
#    'before': 'd7be258fef6da0b4e2fbc61a421c488dea4f22a5',
#    'commits': [{'sha': '57790bff988ef155051081c930957c46e90823a3',
#      'author': {'email': 'idleberg@users.noreply.github.com',
#       'name': 'idleberg'},
#      'message': 'deploy: 362eb168b8382bff2cd2decc070853fd0ae16194',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/atom-packages/feed/commits/57790bff988ef155051081c930957c46e90823a3'}]},
#   'public': True,
#   'created_at': '2022-03-07T19:16:41Z',
#   'org': {'id': 87246565,
#    'login': 'atom-packages',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/atom-packages',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/87246565?'}},
#  {'id': '20622924519',
#   'type': 'DeleteEvent',
#   'actor': {'id': 49699333,
#    'login': 'dependabot[bot]',
#    'display_login': 'dependabot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49699333?'},
#   'repo': {'id': 431458160,
#    'name': 'dsp-testing/ex',
#    'url': 'https://api.github.com/repos/dsp-testing/ex'},
#   'payload': {'ref': 'dependabot/go_modules/github.com/honeycombio/beeline-go-1.6.0',
#    'ref_type': 'branch',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2022-03-07T19:16:41Z',
#   'org': {'id': 30846345,
#    'login': 'dsp-testing',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/dsp-testing',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/30846345?'}},
#  {'id': '20622924517',
#   'type': 'CreateEvent',
#   'actor': {'id': 98309327,
#    'login': 'pravinbindassdeal',
#    'display_login': 'pravinbindassdeal',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/pravinbindassdeal',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/98309327?'},
#   'repo': {'id': 467227647,
#    'name': 'pravinbindassdeal/meetme',
#    'url': 'https://api.github.com/repos/pravinbindassdeal/meetme'},
#   'payload': {'ref': 'master',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2022-03-07T19:16:41Z'},
#  {'id': '20622924452',
#   'type': 'PushEvent',
#   'actor': {'id': 72747630,
#    'login': 'geonosis-bot',
#    'display_login': 'geonosis-bot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/geonosis-bot',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/72747630?'},
#   'repo': {'id': 314284197,
#    'name': 'geonosis-bot/nijXRxUS7mLdZ8HmHk4HV',
#    'url': 'https://api.github.com/repos/geonosis-bot/nijXRxUS7mLdZ8HmHk4HV'},
#   'payload': {'push_id': 9287792916,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/build',
#    'head': '5b03aba3f194e7cf6ea3a2e035906ba37fbd4ac1',
#    'before': '47a23a6e41ee45d6c742928868bc1be504363050',
#    'commits': [{'sha': '5b03aba3f194e7cf6ea3a2e035906ba37fbd4ac1',
#      'author': {'email': '72747630+geonosis-bot@users.noreply.github.com',
#       'name': 'geonosis-bot'},
#      'message': 'Create CNAME',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/geonosis-bot/nijXRxUS7mLdZ8HmHk4HV/commits/5b03aba3f194e7cf6ea3a2e035906ba37fbd4ac1'}]},
#   'public': True,
#   'created_at': '2022-03-07T19:16:41Z'},
#  {'id': '20622924432',
#   'type': 'PushEvent',
#   'actor': {'id': 99383195,
#    'login': 'kamilakaru',
#    'display_login': 'kamilakaru',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/kamilakaru',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/99383195?'},
#   'repo': {'id': 465858500,
#    'name': 'kamilakaru/alx-system_engineering-devops',
#    'url': 'https://api.github.com/repos/kamilakaru/alx-system_engineering-devops'},
#   'payload': {'push_id': 9287792904,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '8ab771e49ca0e2b201b5af7eaba14dc74c6a1c95',
#    'before': 'db3236d8b696d73179512b532480007c5e451b4d',
#    'commits': [{'sha': '8ab771e49ca0e2b201b5af7eaba14dc74c6a1c95',
#      'author': {'email': 'karukamila@gmail.com', 'name': 'kamilakaru'},
#      'message': 'shell redirections',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/kamilakaru/alx-system_engineering-devops/commits/8ab771e49ca0e2b201b5af7eaba14dc74c6a1c95'}]},
#   'public': True,
#   'created_at': '2022-03-07T19:16:41Z'},
#  {'id': '20622924416',
#   'type': 'CreateEvent',
#   'actor': {'id': 10176704,
#    'login': 'w473',
#    'display_login': 'w473',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/w473',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/10176704?'},
#   'repo': {'id': 438760108,
#    'name': 'w473/geoip-resolver',
#    'url': 'https://api.github.com/repos/w473/geoip-resolver'},
#   'payload': {'ref': 'new-setup-for-kratos',
#    'ref_type': 'branch',
#    'master_branch': 'main',
#    'description': 'Simple service to serve GEOIP data based on GEOLITE by MAXMIND',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2022-03-07T19:16:41Z'},
#  {'id': '20622924471',
#   'type': 'PushEvent',
#   'actor': {'id': 50302161,
#    'login': 'AndreWohnsland',
#    'display_login': 'AndreWohnsland',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/AndreWohnsland',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/50302161?'},
#   'repo': {'id': 185077056,
#    'name': 'AndreWohnsland/CocktailBerry',
#    'url': 'https://api.github.com/repos/AndreWohnsland/CocktailBerry'},
#   'payload': {'push_id': 9287792888,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/dev',
#    'head': 'ce838be507e0b7b941b15cae47037858e6a449c1',
#    'before': '7bcc5611ab7406972e328543a91cdadb826de287',
#    'commits': [{'sha': 'ce838be507e0b7b941b15cae47037858e6a449c1',
#      'author': {'email': '50302161+AndreWohnsland@users.noreply.github.com',
#       'name': 'Andre Wohnsland'},
#      'message': 'Added list len validation',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/AndreWohnsland/CocktailBerry/commits/ce838be507e0b7b941b15cae47037858e6a449c1'}]},
#   'public': True,
#   'created_at': '2022-03-07T19:16:41Z'},
#  {'id': '20622924428',
#   'type': 'PushEvent',
#   'actor': {'id': 71354125,
#    'login': 'aws-connector-for-github[bot]',
#    'display_login': 'aws-connector-for-github',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/aws-connector-for-github[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/71354125?'},
#   'repo': {'id': 429551228,
#    'name': 'bullet-dev-team/python-pyramid-public',
#    'url': 'https://api.github.com/repos/bullet-dev-team/python-pyramid-public'},
#   'payload': {'push_id': 9287792868,
#    'size': 2,
#    'distinct_size': 1,
#    'ref': 'refs/heads/cicd-e2e-5mbgsw',
#    'head': '4df4b52cbf1f342593c450f5d3062c1d6b64b5bd',
#    'before': '61e2ff3b616420ed5cbeded6968270c1d92936e5',
#    'commits': [{'sha': 'aec4ad11734af77039cce2a06953b8b3e6001e04',
#      'author': {'email': '72478731+bullet-dev-team@users.noreply.github.com',
#       'name': 'bullet-dev-team'},
#      'message': 'Update mytemplate.jinja2',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/bullet-dev-team/python-pyramid-public/commits/aec4ad11734af77039cce2a06953b8b3e6001e04'},
#     {'sha': '4df4b52cbf1f342593c450f5d3062c1d6b64b5bd',
#      'author': {'email': 'root@ip-10-0-164-196.eu-west-1.compute.internal',
#       'name': 'root'},
#      'message': "Merge branch 'cicd-v2' of https://codestar-connections.eu-west-1.amazonaws.com/git-http/612793622137/eu-west-1/0e478d9c-42cf-45a4-b42e-036a91438188/bullet-dev-team/python-pyramid-public.git into cicd-e2e-5mbgsw",
#      'distinct': True,
#      'url': 'https://api.github.com/repos/bullet-dev-team/python-pyramid-public/commits/4df4b52cbf1f342593c450f5d3062c1d6b64b5bd'}]},
#   'public': True,
#   'created_at': '2022-03-07T19:16:41Z'}]

# %%
r.json()[0].keys()
# Out:
# dict_keys(['id', 'type', 'actor', 'repo', 'payload', 'public', 'created_at'])

# %% [markdown]
# #### A note on errors and exceptions with the Requests library
#
# There are a number of exceptions and error codes you need to be familiar with when using the Requests library in Python.
#
# - The Requests library will raise a ConnectionError exception if there is a network problem like a DNS failure, or refused connection
# - These are rare, but with invalid HTTP responses, Requests will also raise an HTTPError exception
# - A Timeout exception will be raised if a request times out
# - If and when a request exceeds the preconfigured number of maximum redirections, then a TooManyRedirects exception will be raised

# %% [markdown]
# # Gotta Catch 'Em All! Using the Pokemon API
#
# https://pokeapi.co/
#
# Nice place to start because there's no login details or credentials to fuss with
#
# For now, just want to explore grabbing the Types of different Pokemon.
#
# Useful documentation links:
# - Pokemon endpoint: https://pokeapi.co/docs/v2#pokemon
#     - `https://pokeapi.co/api/v2/pokemon/{id or name}/`
# - Type endpoint: https://pokeapi.co/docs/v2#types
#     - `https://pokeapi.co/api/v2/type/{id or name}/`

# %% [markdown]
# ### Start by exploring the response from the Pokemon endpoint
#
# Going to start with Charmander, pokemon #4, cause he's one of my favorites
#
# <img src="https://i.pinimg.com/originals/e7/0e/d0/e70ed0b54f9230c56c2e3bd2958d68a4.jpg" alt="adorable charmander found via pinterest" width=150>
#
# [Image Source](https://www.pinterest.com/pin/419045940312305352/)

# %%
# First, what endpoint url are we using?
base_poke_url = 'https://pokeapi.co/api/v2/pokemon/'

# %%
# How does that need to adapt for charmander?
charmander_url = base_poke_url + 'charmander/'

charmander_url
# Out:
# 'https://pokeapi.co/api/v2/pokemon/charmander/'

# %%
# Check the status code, will this work?
resp = requests.get(charmander_url)
resp.status_code
# Out:
# 200

# %%
# Now let's actually get the response (as a json)
char_json = resp.json()

# %%
# Let's check out some details about the response
char_json.keys()
# Out:
# dict_keys(['abilities', 'base_experience', 'forms', 'game_indices', 'height', 'held_items', 'id', 'is_default', 'location_area_encounters', 'moves', 'name', 'order', 'past_types', 'species', 'sprites', 'stats', 'types', 'weight'])

# %%
# Check the id
char_json['id']
# Out:
# 4

# %%
# Check the name
char_json['name']
# Out:
# 'charmander'

# %%
# Check the types
char_json['types']
# Out:
# [{'slot': 1,
#   'type': {'name': 'fire', 'url': 'https://pokeapi.co/api/v2/type/10/'}}]

# %% [markdown]
# #### Helper Function!
#
# Let's write a function that, given a response from this API's pokemon endpoint, returns a list of the ID, name, primary type _and secondary type_ for that pokemon.
#
# Note that Charmander here just has one type - what would a pokemon with two types look like? Note that Bulbasaur is both grass and poison types.

# %%
# Code here to explore
bulba_url = base_poke_url + '1/'
bulba = requests.get(bulba_url).json()
bulba['types']
# Out:
# [{'slot': 1,
#   'type': {'name': 'grass', 'url': 'https://pokeapi.co/api/v2/type/12/'}},
#  {'slot': 2,
#   'type': {'name': 'poison', 'url': 'https://pokeapi.co/api/v2/type/4/'}}]

# %%
bulba['types'][0]['type']['name'] #this will pull the first type out of type
# Out:
# 'grass'

# %%
# Now - write the function!
def get_pokemon_details(poke_resp):
    '''
    inputs:
    poke_resp - expects json/dict
    
    outputs: 
    list of id, pokemon name, primary type and secondary type 
    
    if secondary type is not applicable, secondary type will be 'None'
    '''
    poke_id = poke_resp['id']
    
    poke_name = poke_resp['name']
    
    primary_type = poke_resp['types'][0]['type']['name']
    
    if len(poke_resp['types']) == 1:
        
        secondary_type = 'None'
        
    else:
        secondary_type = poke_resp['types'][1]['type']['name']
        
    poke_details_list = [poke_id, poke_name, primary_type, secondary_type]
    
    
    
    
    return poke_details_list

# %%
# Let's test our function on the 3 original starter pokemon
original_starter_ids = list(range(1,10, 3))
print(original_starter_ids)
# Out:
# [1, 4, 7]

# %%
# Run this code to check our work
for poke_id in original_starter_ids:
    url = f"{base_poke_url}{poke_id}/"
    resp = requests.get(url).json()
    details = get_pokemon_details(resp)
    print(details)
# Out:
# [1, 'bulbasaur', 'grass', 'poison']
# [4, 'charmander', 'fire', 'None']
# [7, 'squirtle', 'water', 'None']

# %% [markdown]
# ### Moving to Pandas
#
# Let's get all of these details for all of the original 151 pokemon! And save them to a Pandas dataframe.

# %%
# Need to import panda
import pandas as pd

# %%
# Let's go ahead and define what our columns will be
col_names = ['id', 'name', 'primary_type', 'secondary_type']

# %%
# Define a list of our 151 pokemon ids
original_151 = list(range(1,152))

# %% [markdown]
# So we're going to make 151 requests... don't want to overload the API endpoint! So let's use the `time` library to space out our requests.

# %%
import time

# %%
# Easiest way to do this will be to have a list of lists, then concat them all

# Define a blank list to capture all the pokemon details
row_list = []

# And then loop over our pokemon ids!
# Let's write this together!
for poke_id in original_151:
    url = f"{base_poke_url}{poke_id}/"
    resp = requests.get(url).json()
    details = get_pokemon_details(resp)
    row_list.append(details)
    time.sleep(.5)
    
# Then, concat everything into one df
poke_df = pd.concat([pd.DataFrame([i], columns = col_names) for i in row_list], ignore_index=True)

# %%
poke_df.tail()
# Out:
#       id       name primary_type secondary_type
# 146  147    dratini       dragon           None
# 147  148  dragonair       dragon           None
# 148  149  dragonite       dragon         flying
# 149  150     mewtwo      psychic           None
# 150  151        mew      psychic           None

# %%
# visualize it!
import matplotlib.pyplot as plt

primary_type_count = poke_df.groupby('primary_type').count()['id'].sort_values(ascending=False)

plt.figure(figsize=(10,8))
plt.bar(primary_type_count.index, primary_type_count)

plt.title("Counts of Pokemon Primary Types")
plt.ylabel("Number of Pokemon")
plt.xlabel("Primary Type")
plt.xticks(rotation=45)

plt.show()

# %% [markdown]
# ![monty python gif - and now for something completely different, from giphy](https://media.giphy.com/media/xznyPebL28X5u/giphy.gif)

# %% [markdown]
# # Movie Time!
#
# Let's practice with an API that actually requires some authorization, in the form of an API Key!

# %% [markdown]
# # **NEVER EVER PUT YOUR API KEY ON GITHUB**
#
# Either create a json file with API keys in a different directory, or create a python file with the key saved as a variable that you can call. (There are even more options than that, but these are two easily-accessible ones)

# %%
# Option 1: use a json file saved to some other folder outside your Git repo
# In a new terminal window, create a file called api.json and save the path to that file

# Need to import json to do this
import json

# Define a function to open the json
def get_keys(path):
    with open(path) as f:
        return json.load(f)


# Using the function to open and load all keys in that file 
api_keys = get_keys("/Users/Jordan/Documents/secrets/tmdb.json")

# Setting the first (and only) value as a variable

tmdb_1 = api_keys['tmdb_key']
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-2-ef1d9a31c787> in <module>
#      12
#      13 # Using the function to open and load all keys in that file
# ---> 14 api_keys = get_keys("/Users/Jordan/Documents/secrets/tmdb.json")
#      15
#      16 # Setting the first (and only) value as a variable
#
# <ipython-input-2-ef1d9a31c787> in get_keys(path)
#       8 def get_keys(path):
#       9     with open(path) as f:
# ---> 10         return json.load(f)
#      11
#      12
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/json/__init__.py in load(fp, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     291     kwarg; otherwise ``JSONDecoder`` is used.
#     292     """
# --> 293     return loads(fp.read(),
#     294         cls=cls, object_hook=object_hook,
#     295         parse_float=parse_float, parse_int=parse_int,
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/json/__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     355             parse_int is None and parse_float is None and
#     356             parse_constant is None and object_pairs_hook is None and not kw):
# --> 357         return _default_decoder.decode(s)
#     358     if cls is None:
#     359         cls = JSONDecoder
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/json/decoder.py in decode(self, s, _w)
#     338         end = _w(s, end).end()
#     339         if end != len(s):
# --> 340             raise JSONDecodeError("Extra data", s, end)
#     341         return obj
#     342
#
# JSONDecodeError: Extra data: line 1 column 2 (char 1)

# %%
# Option 2: use a python file that's been added to your .gitignore

# In a new terminal window, create a file called keys.py in this repo
# Save the api key as tmdb_api_key = "[key]"





# Then let's edit our .gitignore file together

# %% [markdown]
# Just as important! You may want to call the variable you've set to check that the API key is rendering correctly - but **be sure to clear the output of that cell** or else the output will show your key! And then if you push to GitHub it'll push that output to the internet which defeats the whole point of saving your key elsewhere!

# %% [markdown]
# ### And now, accessing movie data
#
# Documentation: https://developers.themoviedb.org/3

# %%
# Default URL given as an example... let's see what it is!

example_url = f'https://api.themoviedb.org/3/movie/550?api_key={tmdb_1}

# %%
# Get the response

r = requests.get(example_url)

# %%
r.json

# %%
# Check the keys
r.keys()

# %%
# Find similar movies to the previous id

example_id = r['id']
example_id

# %%
# Check out that response
base_url = 'https://api.themoviedb.org/3/'
# ?api
similar_movie_url = f'{base_url}/movie/{example_id}/similar?api_key={tmdb_1}

# %%
r = requests.get(similar_movie_url).json()

# %%
# How many similar movies did it find?

r['total_results']

# %%
# but is that the length of these results?

len(r['results'])

# %%
# what's in here?

r['results'][0]

# %% [markdown]
# ## Level Up - Another Way to Deal with APIs
#
# Check out [Postman](https://www.getpostman.com/).

# %% [markdown]
# ## Extra Credit - Further Practice
#
# There are many ways to access data through APIs! [Sodapy](https://github.com/xmunoz/sodapy) is the Python client for the Socrata Open Data API.

# %%
# Install before running 
# !pip install sodapy

# %% [markdown]
# #### Tokenize yourself!
#
# https://dev.socrata.com/foundry/data.cityofnewyork.us/fhrw-4uyv
#
# Scroll down and click to sign up for an app token! No credit cards required!

# %%
token = '' # paste your token here 

from sodapy import Socrata

# Unauthenticated client only works with public data sets. Note 'None'
# in place of application token, and no username or password:
client = Socrata("data.cityofnewyork.us", token)

# Example authenticated client (needed for non-public datasets):
# client = Socrata(data.cityofnewyork.us,
#                  MyAppToken,
#                  userame="user@example.com",
#                  password="AFakePassword")

# First 2000 results, returned as JSON from API / converted to Python list of
# dictionaries by sodapy.
results = client.get("fhrw-4uyv", incident_zip = '11004', limit=1000)

# %%
type(results)

# %%
len(results)

# %%
results[0]

# %%
df_soda = pd.DataFrame(results)

print(len(df_soda))
print(df_soda.columns)
df_soda.head()

# %% [markdown]
# ## Even Further Practice
#
# https://github.com/toddmotto/public-apis
#
# Find a buddy, find a free api, get a key, and do a GET. Try to transform the response into a dataframe.
